# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** [Intan Nurul Falah]
# - **Email:** [a200xbm226@devacademy.id]
# - **ID Dicoding:** [A200XBM226]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Apa saja faktor utama yang berdampak pada kualitas udara di 3 stasiun tersebut?
# - Apakah terdapat perbedaan kualitas udara yang signifikan antara satu stasiun dengan yang lain?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
# Mount Google Drive untuk membaca file CSV
import os
from google.colab import drive
drive.mount('/content/drive')

loc = '/content/drive/My Drive/laskar ai/ADP'
os.chdir(loc)

os.getcwd()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '/content/drive/My Drive/laskar ai/ADP'

# %%
aotizhongxin_df = pd.read_csv("/content/drive/MyDrive/laskar ai/ADP/Data/PRSA_Data_Aotizhongxin_20130301-20170228.csv")
aotizhongxin_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
changping_df = pd.read_csv("/content/drive/MyDrive/laskar ai/ADP/Data/PRSA_Data_Changping_20130301-20170228.csv")
changping_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %%
guanyuan_df = pd.read_csv("/content/drive/MyDrive/laskar ai/ADP/Data/PRSA_Data_Guanyuan_20130301-20170228.csv")
guanyuan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  14.0  20.0  300.0  69.0  -0.7
# 1   2  2013      3    1     1    4.0   4.0  13.0  17.0  300.0  72.0  -1.1
# 2   3  2013      3    1     2    3.0   3.0  10.0  19.0  300.0  69.0  -1.1
# 3   4  2013      3    1     3    3.0   6.0   7.0  24.0  400.0  62.0  -1.4
# 4   5  2013      3    1     4    3.0   6.0   5.0  14.0  400.0  71.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1023.0 -18.8   0.0  NNW   4.4  Guanyuan
# 1  1023.2 -18.2   0.0    N   4.7  Guanyuan
# 2  1023.5 -18.2   0.0  NNW   5.6  Guanyuan
# 3  1024.5 -19.4   0.0   NW   3.1  Guanyuan
# 4  1025.2 -19.5   0.0    N   2.0  Guanyuan

# %% [markdown]
# **Insight:**
# Seluruh data berhasil dimuat, terdapat 18 kolom yang tersedia, yaitu
# - No
# - Year
# - Month
# - Day
# - Hour
# - PM2.5
# - PM10
# - SO2
# - NO2
# - CO
# - O3
# - TEMP
# - PRES
# - DEWP
# - RAIN
# - wd
# - WSPM
# - Station

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# # Data aotizhongxin_df

# %%
aotizhongxin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
aotizhongxin_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34139.000000  34346.000000  34129.000000  34041.000000  33288.000000
# mean      82.773611    110.060391     17.375901     59.305833   1262.945145
# ...

# %%
aotizhongxin_df.nunique()
# Out:
# No         35064
# year           5
# month         12
# day           31
# hour          24
# PM2.5        545
# PM10         633
# SO2          330
# NO2          465
# CO           112
# O3           831
# TEMP         967
# PRES         600
# DEWP         604
# RAIN         127
# wd            16
# WSPM          91
# station        1
# dtype: int64

# %%
aotizhongxin_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", aotizhongxin_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# # Data changping_df

# %%
changping_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
changping_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34290.000000  34482.000000  34436.000000  34397.000000  33543.000000
# mean      71.099743     94.657871     14.958906     44.182086   1152.301345
# ...

# %%
changping_df.nunique()
# Out:
# No         35064
# year           5
# month         12
# day           31
# hour          24
# PM2.5        481
# PM10         562
# SO2          294
# NO2          459
# CO           115
# O3           886
# TEMP         998
# PRES         592
# DEWP         602
# RAIN         116
# wd            16
# WSPM          95
# station        1
# dtype: int64

# %%
changping_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       774
# PM10        582
# SO2         628
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", changping_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
changping_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34290.000000  34482.000000  34436.000000  34397.000000  33543.000000
# mean      71.099743     94.657871     14.958906     44.182086   1152.301345
# ...

# %% [markdown]
# # Data guanyuan_df

# %%
guanyuan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34448 non-null  float64
#  6   PM10     34635 non-null  float64
#  7   SO2      34590 non-null  float64
#  8   NO2      34405 non-null  float64
#  9   CO       33311 non-null  float64
#  10  O3       33891 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
guanyuan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       616
# PM10        429
# SO2         474
# NO2         659
# CO         1753
# O3         1173
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
guanyuan_df.nunique()
# Out:
# No         35064
# year           5
# month         12
# day           31
# hour          24
# PM2.5        557
# PM10         630
# SO2          280
# NO2          376
# CO           117
# O3           767
# TEMP         967
# PRES         600
# DEWP         604
# RAIN         127
# wd            16
# WSPM          91
# station        1
# dtype: int64

# %%
print("Jumlah duplikasi: ", guanyuan_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
guanyuan_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34448.000000  34635.000000  34590.000000  34405.000000  33311.000000
# mean      82.933372    109.023303     17.590941     57.901643   1271.294377
# ...

# %% [markdown]
# **Insight:**
# Tabel telah dibersihkan dari duplikasi (duplicate rows), namun masih ditemukan missing values (NaN) di sejumlah baris. Distribusi nilai NaN tersebar secara tidak merata di beberapa kolom, dan perlu penanganan lebih lanjut sebelum dilakukan pemodelan atau analisis lanjutan.

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Karena berdasarkan Assessing Data tidak ditemukan duplikasi tetapi ditemukan missing value, maka pada cleaning data saya hanya akan menangani missing value

# %%
# List semua Data
csv_urls = [
    "/content/drive/MyDrive/laskar ai/ADP/Data/PRSA_Data_Aotizhongxin_20130301-20170228.csv",
    "/content/drive/MyDrive/laskar ai/ADP/Data/PRSA_Data_Changping_20130301-20170228.csv",
    "/content/drive/MyDrive/laskar ai/ADP/Data/PRSA_Data_Guanyuan_20130301-20170228.csv",
]

# Menyimpan setiap DataFrame
df_list = []

# Baca semua file CSV
for url in csv_urls:
    df = pd.read_csv(url)
    df_list.append(df)

# Gabungkan
merged_df = pd.concat(df_list, ignore_index=True)

# Simpan file (jk diperlukan lagi)
merged_df.to_csv("merged_air_quality.csv", index=False)

merged_df = pd.read_csv("merged_air_quality.csv")
merged_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %% [markdown]
# #### Cleaning Tabel merged_df

# %% [markdown]
# **1. Missing Value**

# %%
merged_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5      2315
# PM10       1729
# SO2        2037
# NO2        2349
# CO         5050
# O3         3496
# TEMP         93
# PRES         90
# DEWP         93
# RAIN         91
# wd          302
# WSPM         71
# station       0
# dtype: int64

# %%
merged_df[merged_df.isna().any(axis=1)]
# Out:
#            No  year  month  day  hour  PM2.5   PM10      SO2       NO2  \
# 74         75  2013      3    4     2   34.0   62.0      NaN   14.0000
# 75         76  2013      3    4     3   12.0   34.0   6.0000   12.0000
# 76         77  2013      3    4     4    7.0   18.0  14.0000       NaN
# 124       125  2013      3    6     4  192.0  203.0  83.6808  140.4252
# 170       171  2013      3    8     2  339.0  400.0      NaN  162.0000
# ...       ...   ...    ...  ...   ...    ...    ...      ...       ...
# 105171  35044  2017      2   28     3    NaN    NaN      NaN       NaN
# 105172  35045  2017      2   28     4    NaN    NaN      NaN       NaN
# 105173  35046  2017      2   28     5    NaN    NaN      NaN       NaN
# 105174  35047  2017      2   28     6    NaN    NaN      NaN       NaN
# 105175  35048  2017      2   28     7    NaN    NaN      NaN       NaN
#
#             CO    O3  TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
missing_percent = (merged_df.isna().mean() * 100).sort_values(ascending=False)
print(missing_percent)
# Out:
# CO         4.800745
# O3         3.323447
# NO2        2.233060
# PM2.5      2.200738
# SO2        1.936459
# PM10       1.643661
# wd         0.287094
# DEWP       0.088410
# TEMP       0.088410
# RAIN       0.086508
# PRES       0.085558
# WSPM       0.067496
# year       0.000000
# No         0.000000
# day        0.000000
# month      0.000000
# hour       0.000000
# station    0.000000
# dtype: float64

# %% [markdown]
# **2. Duplicate**

# %%
print("Berapa Data Yang Duplicate: ", merged_df.duplicated().sum())
# Out:
# Berapa Data Yang Duplicate:  0

# %% [markdown]
# **Imputasi data dengan median**

# %%
pollutant_cols = ["PM2.5", "PM10", "SO2", "NO2", "O3", "CO"]
merged_df[pollutant_cols] = merged_df[pollutant_cols].fillna(merged_df[pollutant_cols].median())

# %% [markdown]
# **Imputasi data dengan mode**

# %%
merged_df["wd"] = merged_df["wd"].fillna(merged_df["wd"].mode()[0])

# %%
merged_df.isna().sum()
# Out:
# No          0
# year        0
# month       0
# day         0
# hour        0
# PM2.5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP       93
# PRES       90
# DEWP       93
# RAIN       91
# wd          0
# WSPM       71
# station     0
# dtype: int64

# %%
# Menyusun ulang nilai pada kolom 'No' agar terisi secara berurutan dari 1 hingga jumlah baris dalam tabel
merged_df["No"] = range(1, len(merged_df) + 1)

# Hasil
print(merged_df[["station", "No"]].head())
# Out:
#         station  No
# 0  Aotizhongxin   1
# 1  Aotizhongxin   2
# 2  Aotizhongxin   3
# 3  Aotizhongxin   4
# 4  Aotizhongxin   5

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105192 entries, 0 to 105191
# Data columns (total 18 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   No       105192 non-null  int64
#  1   year     105192 non-null  int64
#  2   month    105192 non-null  int64
#  3   day      105192 non-null  int64
#  4   hour     105192 non-null  int64
#  5   PM2.5    105192 non-null  float64
#  6   PM10     105192 non-null  float64
#  7   SO2      105192 non-null  float64
#  8   NO2      105192 non-null  float64
#  9   CO       105192 non-null  float64
#  10  O3       105192 non-null  float64
#  11  TEMP     105099 non-null  float64
#  12  PRES     105102 non-null  float64
#  13  DEWP     105099 non-null  float64
#  14  RAIN     105101 non-null  float64
#  15  wd       105192 non-null  object
#  16  WSPM     105121 non-null  float64
#  17  station  105192 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 14.4+ MB

# %%
merged_df.describe()
# Out:
#                   No           year         month            day  \
# count  105192.000000  105192.000000  105192.00000  105192.000000
# mean    52596.500000    2014.662560       6.52293      15.729637
# std     30366.459096       1.177202       3.44872       8.800134
# min         1.000000    2013.000000       1.00000       1.000000
# 25%     26298.750000    2014.000000       4.00000       8.000000
# 50%     52596.500000    2015.000000       7.00000      16.000000
# 75%     78894.250000    2016.000000      10.00000      23.000000
# max    105192.000000    2017.000000      12.00000      31.000000
#
#                 hour          PM2.5           PM10            SO2  \
# count  105192.000000  105192.000000  105192.000000  105192.000000
# mean       11.500000      78.409312     104.208752      16.473816
# std         6.922219      77.986964      89.780937      22.337953
# min         0.000000       2.000000       2.000000       0.285600
# ...

# %% [markdown]
# **Simpan Data**

# %%
folder_name = "dashboard"
os.makedirs(folder_name, exist_ok=True)  # Buat Folder Baru

file_path = os.path.join(folder_name, "cleaned_data.csv")
merged_df.to_csv(file_path, index=False)

# %% [markdown]
# **Insight:**
# - Dari data yang mempunyai missing value dengan tipe data numerik, saya melakukan imputasi menggunakan median data dengan tipe data numerik tersebut ialah: PM2.5, PM10, SO2, NO2, CO, O3
# - Dari data yang mempunyai missing value dengan tipe data kategorikal, saya melakukan imputasi menggunakan modus data dengan tipe data kategorikal tersebut ialah: TEMP, PRES, DEWP, RAIN, wd, WSPM

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
merged_df.describe(include="all")
# Out:
#                    No           year         month            day  \
# count   105192.000000  105192.000000  105192.00000  105192.000000
# unique            NaN            NaN           NaN            NaN
# top               NaN            NaN           NaN            NaN
# freq              NaN            NaN           NaN            NaN
# mean     52596.500000    2014.662560       6.52293      15.729637
# std      30366.459096       1.177202       3.44872       8.800134
# min          1.000000    2013.000000       1.00000       1.000000
# 25%      26298.750000    2014.000000       4.00000       8.000000
# 50%      52596.500000    2015.000000       7.00000      16.000000
# 75%      78894.250000    2016.000000      10.00000      23.000000
# max     105192.000000    2017.000000      12.00000      31.000000
#
#                  hour          PM2.5           PM10            SO2  \
# count   105192.000000  105192.000000  105192.000000  105192.000000
# ...

# %%
merged_df.No.duplicated
# Out:
# <bound method Series.duplicated of 0              1
# 1              2
# 2              3
# 3              4
# 4              5
#            ...
# 105187    105188
# 105188    105189
# 105189    105190
# 105190    105191
# 105191    105192
# Name: No, Length: 105192, dtype: int64>

# %%
merged_df.No.is_unique
# Out:
# True

# %%
merged_df.groupby(by="station").No.nunique().sort_values(ascending=False)
# Out:
# station
# Aotizhongxin    35064
# Changping       35064
# Guanyuan        35064
# Name: No, dtype: int64

# %%
merged_df.groupby(by="station").agg({
    "No": "nunique",
    "PM2.5": ["max", "min", "mean", "std", ]
})
# Out:
#                   No  PM2.5
#              nunique    max  min       mean        std
# station
# Aotizhongxin   35064  898.0  3.0  82.040934  81.167179
# Changping      35064  882.0  2.0  70.744359  71.563284
# Guanyuan       35064  680.0  2.0  82.442642  80.303309

# %%
merged_df.groupby(by="station").agg({
    "No": "nunique",
    "PM10": ["max", "min", "mean", "std", ]
})
# Out:
#                   No   PM10
#              nunique    max  min        mean        std
# station
# Aotizhongxin   35064  984.0  2.0  109.485803  94.326755
# Changping      35064  999.0  2.0   94.447773  82.762130
# Guanyuan       35064  999.0  2.0  108.692679  91.060249

# %% [markdown]
# **Insight:**
#
# Eksplorasi awal menunjukkan bahwa tabel gabungan telah memiliki kolom No dengan nilai yang unik. Setiap stasiun tercatat memiliki sebanyak 35.064 baris data. Analisis deskriptif dilakukan terhadap variabel PM2.5 dan PM10 di masing-masing stasiun, meliputi nilai maksimum, minimum, rata-rata (mean), dan standar deviasi (std).

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Apa saja faktor utama yang berdampak pada kualitas udara di 3 stasiun tersebut?

# %%
# Hitung korelasi antara variabel
correlation_matrix = merged_df[["PM2.5","PM10","SO2","NO2","O3","CO","TEMP","PRES","DEWP","RAIN", "WSPM"]].corr()

# Visualisasi korelasi dengan heatmap
plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Korelasi Faktor Lingkungan dengan PM2.5")
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=merged_df, x="station", y="PM2.5")
plt.title("Distribusi PM2.5 di Tiap Stasiun")
plt.xlabel("Stasiun")
plt.ylabel("Konsentrasi PM2.5")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=merged_df, x="station", y="PM10")
plt.title("Distribusi PM10 di Tiap Stasiun")
plt.xlabel("Stasiun")
plt.ylabel("Konsentrasi PM2.5")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Analisis Lanjutan

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# %%
forecast_results = {}

# %%
# Menjalankan proses secara terpisah untuk masing-masing stasiun.
for station in merged_df["station"].unique():
    print(f"Processing {station}...")

    # Mengambil data masing-masing stasiun
    station_data = merged_df[merged_df["station"] == station]
    station_data = station_data.groupby(["year", "month"])["PM2.5"].mean().dropna()

    # Konversi format time series
    station_data.index = pd.to_datetime(station_data.index.map(lambda x: f"{x[0]}-{x[1]}"))

    # Pengecekan data untuk ARIMA
    if len(station_data) < 24:  # Minimum 2 tahun data
        print(f"Data untuk {station} terlalu sedikit, dilewati...\n")
        continue

    # Pembuatan Model ARIMA
    try:
        model = ARIMA(station_data, order=(2,1,2))
        model_fit = model.fit()

        # Predict Untuk 6 Bulan Kedepan
        forecast = model_fit.forecast(steps=6)

        # Simpan hasil prediksi
        forecast_results[station] = forecast

        # Plot hasil prediksi
        plt.figure(figsize=(10,5))
        plt.plot(station_data, label="Data Aktual")
        plt.plot(forecast, label="Prediksi", linestyle="dashed", color="red")
        plt.xlabel("Waktu")
        plt.ylabel("PM2.5")
        plt.title(f"Prediksi Polusi Udara (PM2.5) - {station}")
        plt.legend()
        plt.show()

    except Exception as e:
        print(f"Error saat memproses {station}: {e}\n")
# Out:
# Processing Aotizhongxin...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# Processing Changping...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# ...

# %%
# Predict Conversion
forecast_df = pd.DataFrame(forecast_results)
print("Hasil Prediksi:\n", forecast_df)
# Out:
# Hasil Prediksi:
#              Aotizhongxin  Changping   Guanyuan
# 2017-03-01     73.098919  67.246786  77.137751
# 2017-04-01     84.707560  70.440226  84.749722
# 2017-05-01     82.566029  70.354049  83.509051
# 2017-06-01     81.858287  71.059218  82.233180
# 2017-07-01     82.173446  70.671885  82.492279
# 2017-08-01     82.185695  71.020598  82.704363

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler # Import StandardScaler

# Normalisasi data sebelum PCA
scaler = StandardScaler()
data_scaled = scaler.fit_transform(merged_df[["PM2.5", "PM10", "NO2", "SO2", "CO", "O3"]].dropna())

# Jalankan PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(data_scaled)

# Variansi yang dijelaskan oleh setiap komponen
print("Explained variance ratio:", pca.explained_variance_ratio_)

# Scatter plot hasil PCA
plt.scatter(pca_result[:, 0], pca_result[:, 1], alpha=0.5)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA Analysis")
plt.show()
# Out:
# Explained variance ratio: [0.60758127 0.174452  ]

# %%
from sklearn.ensemble import IsolationForest

# Menentukan Fitur yang Digunakan
features = merged_df[["PM2.5", "PM10", "NO2", "SO2", "CO", "O3"]].dropna()

# Pemodelanm ISF
iso_forest = IsolationForest(contamination=0.05, random_state=42)
merged_df["anomaly"] = iso_forest.fit_predict(features)

# Anomali
print(merged_df[merged_df["anomaly"] == -1][["station", "year", "month", "PM2.5"]])
# Out:
#              station  year  month  PM2.5
# 57      Aotizhongxin  2013      3   83.0
# 105     Aotizhongxin  2013      3  114.0
# 106     Aotizhongxin  2013      3  131.0
# 107     Aotizhongxin  2013      3  138.0
# 108     Aotizhongxin  2013      3  142.0
# ...              ...   ...    ...    ...
# 104811      Guanyuan  2017      2  203.0
# 104876      Guanyuan  2017      2  286.0
# 104877      Guanyuan  2017      2  274.0
# 104880      Guanyuan  2017      2  267.0
# 104881      Guanyuan  2017      2  262.0
#
# [5260 rows x 4 columns]

# %% [markdown]
# ## Conclusion

# %% [markdown]
# **Conclution pertanyaan 1**
#
# Faktor-Faktor yang Memiliki Korelasi Tinggi dengan PM2.5:
# 1. PM10 (0.87) menunjukkan hubungan korelasi yang sangat kuat dengan PM2.5. Hal ini masuk akal karena PM2.5 merupakan fraksi dari partikel yang termasuk dalam PM10, sehingga pergerakannya cenderung selaras.
# 2. CO (0.76) atau karbon monoksida memiliki korelasi yang tinggi dengan PM2.5, mengindikasikan bahwa kedua polutan ini kemungkinan berasal dari sumber emisi yang sama, seperti kendaraan bermotor dan pembakaran bahan bakar.
# 3. NO2 (0.68) atau nitrogen dioksida juga menunjukkan hubungan korelatif yang cukup signifikan dengan PM2.5, mengarah pada dugaan kontribusi dari sektor transportasi dan industri.
# 4. SO2 (0.48) memperlihatkan korelasi sedang dengan PM2.5, yang mungkin berhubungan dengan aktivitas pembakaran batu bara atau emisi industri lainnya.
#
# Faktor-Faktor yang Berkorelasi Negatif terhadap PM2.5 (Kemungkinan Berperan dalam Menurunkan Polusi):
# 1. O3 (-0.13) atau ozon tampak memiliki korelasi negatif dengan PM2.5, kemungkinan disebabkan oleh interaksi kimia di atmosfer yang membantu menurunkan konsentrasi partikel saat kadar ozon meningkat.
# 2. Temperatur (-0.12) menunjukkan korelasi negatif lemah dengan PM2.5. Peningkatan suhu dapat membantu mengurangi kadar polutan, mungkin karena sirkulasi udara yang lebih baik atau proses atmosferik lainnya.
# 3. Tekanan udara (-0.07) memiliki korelasi yang sangat rendah, menandakan bahwa variabel ini tidak berpengaruh besar terhadap fluktuasi PM2.5.
# 4. Curah hujan (-0.01) hanya menunjukkan sedikit korelasi negatif, yang berarti dalam dataset ini, efek pencucian partikel oleh hujan terhadap PM2.5 tidak terlalu signifikan.
#
# **Conclution pertanyaan 2:**
# 1. Visualisasi menggunakan boxplot menggambarkan distribusi PM2.5 di masing-masing stasiun pengukuran.
# 2. Secara umum, median PM2.5 di hampir semua stasiun berada pada level yang serupa, menandakan tingkat konsentrasi yang relatif homogen.
# 3. Ditemukan sejumlah outlier yang menandakan adanya kejadian polusi ekstrem pada waktu-waktu tertentu di beberapa lokasi.
# 4. Rentang interkuartil (IQR) antar stasiun juga cenderung sebanding, menunjukkan tingkat variabilitas PM2.5 yang tidak jauh berbeda antar lokasi pemantauan.
